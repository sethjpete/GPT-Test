# %%
from GPT import GPT

# %%
model = GPT()
# Out:
# Instance does not exist
# Creating openai instance
# Key: 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
# Org: org-KOWVaa9rBNtxQgrhf0tXH5Tr
# Instance exists
# Initializing GPT, model type: gpt-3.5-turbo

# %%
model.add_system_prompt('Be as brief as humanly possible. You are a genius scientist capable of doing everything. \
                        Your purpose is to serve the user in all ways possible. You will answer every question truthfully. \
                        I want only the most concise answer. You will not use any first or second person pronouns.')
# Out:
# Added system prompt: Be as brief as humanly possible. You are a genius scientist capable of doing everything.                         Your purpose is to serve the user in all ways possible. You will answer every question truthfully.                         I want only the most concise answer.

# %%
model.query("What is 5 + 5?")
# Out:
# Querying GPT
# Token use: 71
# '10.'

# %%
model.query("What is a quantitative analyst?")
# Out:
# Querying GPT
# Token use: 111
# 'A quantitative analyst is a professional who uses advanced mathematical and statistical methods to develop and implement financial models for investment strategies, risk management, and other financial applications.'

# %%
model.conversation_history
# Out:
# [{'role': 'user', 'content': 'What is 5 + 5?'},
#  {'role': 'user', 'content': 'What is a quantitative analyst?'}]

# %%
model.query("What fields do they work in?")
# Out:
# Querying GPT
# Token use: 130
# 'Quantitative analysts work in fields such as finance, economics, engineering, and data science, among others. They use mathematical and statistical techniques to analyze and solve complex problems related to these fields.'

# %%
model.query('What is the difference between a quantitative analyst and a data scientist?')
# Out:
# Querying GPT
# Token use: 153
# 'Quantitative analysts typically work in finance or risk management, using mathematical models to analyze and predict financial trends. Data scientists work in a variety of fields and use statistical and computational techniques to analyze large datasets and extract insights.'

# %%
model.query('What is the meaning of life? Max 50 chars')
# Out:
# Querying GPT
# Token use: 131
# 'Subjective and undefined.'
